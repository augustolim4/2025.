# %% [markdown]
# <a href="https://colab.research.google.com/github/augustolim4/2025./blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Primeira competição de programação dá start")
ano = "II"
print(ano, "Competição de programação da estática")


livro_ficcao = 8
livro_infantil = 6
livro_n_ficcao = 8
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
print(pontos_rodrigo)
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")


total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))


figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)


figurinhas_joao = 2 * figurinhas_amigo
print(f"João recebeu {figurinhas_joao} figurinhas")

numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))


if numero_de_alunos + numero_de_monitores <= 50:
    print("Pode ir")
else:
    print("Não pode ir")
# Out:
# Primeira competição de programação dá start
# II Competição de programação da estática
# 22
# Os pontos totais do Rodrigo são 22
# Digite o total de figurinhas: 1
# Digite o número de amigos: 100
# João recebeu 0 figurinhas
# Digite a quantidade de alunos: 22
# Digite a quantidade de monitores: 34
# Não pode ir
